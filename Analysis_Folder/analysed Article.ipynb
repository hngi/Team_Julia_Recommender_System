# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\okunato oluwanifemi\Desktop\New folder (2)\Articles CSV.csv')
print(df)
# Out:
#     ArticleID                                              Title  \
# 0         143                       What you have learned so far
# 1         278                              Good Afternoon People
# 2         353       TWO YEARS IN THE TRENCHES BUILDING HOTELS.NG
# 3         355                HOW TO AVOID BEING A ONE-HIT WONDER
# 4         355                HOW TO AVOID BEING A ONE-HIT WONDER
# 5         360                           EVALUATING STARTUP IDEAS
# 6         360                           EVALUATING STARTUP IDEAS
# 7         360                           EVALUATING STARTUP IDEAS
# 8         371                                      Lucid is back
# 9         371                                      Lucid is back
# 10        371                                      Lucid is back
# 11        371                                      Lucid is back
# 12        371                                      Lucid is back
# ...

# %%
conn= df["ArticleID"].value_counts()

conn
# Out:
# 998     9
# 992     7
# 371     6
# 1007    5
# 993     4
# 985     4
# 439     3
# 360     3
# 999     3
# 996     3
# 1002    2
# 355     2
# 986     2
# 983     2
# 995     1
# 375     1
# 143     1
# 278     1
# 353     1
# Name: ArticleID, dtype: int64

# %%
# saving user id and no of followers

conn.to_csv('conn.csv')

columns= ("ArticleID", "Count")
newframe= pd.read_csv("conn.csv", names= columns)

newframe.head()
# Out:
# C:\Users\okunato oluwanifemi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until
#    ArticleID  Count
# 0        998      9
# 1        992      7
# 2        371      6
# 3       1007      5
# 4        993      4

# %%
merged_col = pd.merge(df, newframe, on='ArticleID')

merged_col.head()

complete= merged_col.drop_duplicates()

complete.head()
# Out:
#    ArticleID                                         Title  \
# 0        143                  What you have learned so far
# 1        278                         Good Afternoon People
# 2        353  TWO YEARS IN THE TRENCHES BUILDING HOTELS.NG
# 3        355           HOW TO AVOID BEING A ONE-HIT WONDER
# 5        360                      EVALUATING STARTUP IDEAS
#
#                                              Content  Count
# 0  1.  I have learnt how to publish and article, ...      1
# 1                                                Hey      1
# 2  Hotels.ng is about two years old now. In the f...      1
# 3  Most people, at some point, have a hit. Some h...      2
# 5  The only true currency we humans have is time....      3
